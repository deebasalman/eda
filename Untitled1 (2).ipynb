# %%
import pandas as pd
data=pd.read_csv("https://raw.githubusercontent.com/sunnysavita10/Statistics-With-Python-TheCompleteGuide/main/googleplaystore.csv")
data.head()
# Out:
#                                                  App        Category  Rating  \
# 0     Photo Editor & Candy Camera & Grid & ScrapBook  ART_AND_DESIGN     4.1
# 1                                Coloring book moana  ART_AND_DESIGN     3.9
# 2  U Launcher Lite – FREE Live Cool Themes, Hide ...  ART_AND_DESIGN     4.7
# 3                              Sketch - Draw & Paint  ART_AND_DESIGN     4.5
# 4              Pixel Draw - Number Art Coloring Book  ART_AND_DESIGN     4.3
#
#   Reviews  Size     Installs  Type Price Content Rating  \
# 0     159   19M      10,000+  Free     0       Everyone
# 1     967   14M     500,000+  Free     0       Everyone
# 2   87510  8.7M   5,000,000+  Free     0       Everyone
# 3  215644   25M  50,000,000+  Free     0           Teen
# 4     967  2.8M     100,000+  Free     0       Everyone
#
#                       Genres      Last Updated         Current Ver  \
# 0               Art & Design   January 7, 2018               1.0.0
# ...

# %%
data_copy=data.copy()

# %%
data_copy["Size"]=data_copy["Size"].str.replace("M","000")

# %%
''

# %%
data_copy["Size"]=data_copy["Size"].str.replace("k","")

# %%
data_copy["Size"].unique()
# Out:
# array(['19000', '14000', '8.7000', '25000', '2.8000', '5.6000', '29000',
#        '33000', '3.1000', '28000', '12000', '20000', '21000', '37000',
#        '2.7000', '5.5000', '17000', '39000', '31000', '4.2000', '7.0000',
#        '23000', '6.0000', '6.1000', '4.6000', '9.2000', '5.2000', '11000',
#        '24000', 'Varies with device', '9.4000', '15000', '10000',
#        '1.2000', '26000', '8.0000', '7.9000', '56000', '57000', '35000',
#        '54000', '201', '3.6000', '5.7000', '8.6000', '2.4000', '27000',
#        '2.5000', '16000', '3.4000', '8.9000', '3.9000', '2.9000', '38000',
#        '32000', '5.4000', '18000', '1.1000', '2.2000', '4.5000', '9.8000',
#        '52000', '9.0000', '6.7000', '30000', '2.6000', '7.1000', '3.7000',
#        '22000', '7.4000', '6.4000', '3.2000', '8.2000', '9.9000',
#        '4.9000', '9.5000', '5.0000', '5.9000', '13000', '73000', '6.8000',
#        '3.5000', '4.0000', '2.3000', '7.2000', '2.1000', '42000',
# ...

# %%
import numpy as np
data_copy["Size"]=data_copy["Size"].str.replace("Varies with device",str(np.nan))

# %%
data_copy["Size"]=data_copy["Size"].str.replace("+","")
# Out:
# <ipython-input-7-a68b25b22429>:1: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   data_copy["Size"]=data_copy["Size"].str.replace("+","")

# %%
data_copy["Size"]=data_copy["Size"].str.replace(",","")

# %%
data_copy[~data_copy.Size.str.isnumeric()]
# Out:
#                                                      App             Category  \
# 2      U Launcher Lite – FREE Live Cool Themes, Hide ...       ART_AND_DESIGN
# 4                  Pixel Draw - Number Art Coloring Book       ART_AND_DESIGN
# 5                             Paper flowers instructions       ART_AND_DESIGN
# 9                          Kids Paint Free - Drawing Fun       ART_AND_DESIGN
# 15                       Learn To Draw Kawaii Characters       ART_AND_DESIGN
# ...                                                  ...                  ...
# 10834                                      FR Calculator               FAMILY
# 10835                                           FR Forms             BUSINESS
# 10837                   Fr. Mike Schmitz Audio Teachings               FAMILY
# 10838                             Parkinson Exercices FR              MEDICAL
# 10839                      The SCP Foundation DB fr nn5n  BOOKS_AND_REFERENCE
#
# ...

# %%
data_copy["Size"]=data_copy['Size'].astype("float")

# %%
data_copy.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10841 entries, 0 to 10840
# Data columns (total 13 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   App             10841 non-null  object
#  1   Category        10841 non-null  object
#  2   Rating          9367 non-null   float64
#  3   Reviews         10841 non-null  object
#  4   Size            9146 non-null   float64
#  5   Installs        10841 non-null  object
#  6   Type            10840 non-null  object
#  7   Price           10841 non-null  object
#  8   Content Rating  10840 non-null  object
#  9   Genres          10841 non-null  object
#  10  Last Updated    10841 non-null  object
#  11  Current Ver     10833 non-null  object
#  12  Android Ver     10838 non-null  object
# dtypes: float64(2), object(11)
# memory usage: 1.1+ MB

# %%
for i in data_copy["Size"]:
  if i<10:
    data_copy["Size"]=data_copy["Size"].replace(i,i*1000)

# %%
data_copy["Size"]
# Out:
# 0        19000.0
# 1        14000.0
# 2         8700.0
# 3        25000.0
# 4         2800.0
#           ...
# 10836    53000.0
# 10837     3600.0
# 10838     9500.0
# 10839        NaN
# 10840    19000.0
# Name: Size, Length: 10841, dtype: float64

# %%
removed_item=[",","+","$"]
col_cln=["Installs","Price"]
for i in removed_item:
  for col in col_cln:
    data_copy[col]=data_copy[col].str.replace(i,"")
# Out:
# <ipython-input-14-346801ebb67f>:5: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   data_copy[col]=data_copy[col].str.replace(i,"")

# %%
data_copy.sample(5)
# Out:
#                                        App      Category  Rating Reviews  \
# 6393        Capital Bk Mobile Business Dep       FINANCE     NaN       1
# 7981  CV (Curriculum Vitae / Resume) Maker      BUSINESS     NaN       4
# 8485                             e-Boks.dk  PRODUCTIVITY     3.2    6752
# 7779                 Deck Simulator for CR         TOOLS     3.4     202
# 7227                 CE SODEXO PASS FRANCE  PRODUCTIVITY     NaN       0
#
#          Size Installs  Type Price Content Rating        Genres  \
# 6393   4100.0      100  Free     0       Everyone       Finance
# 7981   4400.0     5000  Free     0       Everyone      Business
# 8485   3300.0  1000000  Free     0       Everyone  Productivity
# 7779  12000.0    10000  Free     0       Everyone         Tools
# 7227  21000.0       50  Free     0       Everyone  Productivity
#
#            Last Updated Current Ver   Android Ver
# 6393   February 3, 2016       1.4.8    4.1 and up
# ...

# %%
data_copy["Installs"].unique()
# Out:
# array(['10000', '500000', '5000000', '50000000', '100000', '50000',
#        '1000000', '10000000', '5000', '100000000', '1000000000', '1000',
#        '500000000', '50', '100', '500', '10', '1', '5', '0', 'Free'],
#       dtype=object)

# %%
data_copy[~data_copy["Installs"].str.isnumeric()]
# Out:
#                                            App Category  Rating Reviews  \
# 10472  Life Made WI-Fi Touchscreen Photo Frame      1.9    19.0    3.0M
#
#          Size Installs Type     Price Content Rating             Genres  \
# 10472  1000.0     Free    0  Everyone            NaN  February 11, 2018
#
#       Last Updated Current Ver Android Ver
# 10472       1.0.19  4.0 and up         NaN

# %%
data_copy=data_copy.drop(data_copy.index[10472])

# %%
data_copy["Installs"]=data_copy["Installs"].astype("int")

# %%
data_copy["Price"]=data_copy["Price"].astype("float")

# %%
data.head(2)
# Out:
#                                               App        Category  Rating  \
# 0  Photo Editor & Candy Camera & Grid & ScrapBook  ART_AND_DESIGN     4.1
# 1                             Coloring book moana  ART_AND_DESIGN     3.9
#
#   Reviews Size  Installs  Type Price Content Rating  \
# 0     159  19M   10,000+  Free     0       Everyone
# 1     967  14M  500,000+  Free     0       Everyone
#
#                       Genres      Last Updated Current Ver   Android Ver
# 0               Art & Design   January 7, 2018       1.0.0  4.0.3 and up
# 1  Art & Design;Pretend Play  January 15, 2018       2.0.0  4.0.3 and up

# %%
data_copy.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 10840 entries, 0 to 10840
# Data columns (total 13 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   App             10840 non-null  object
#  1   Category        10840 non-null  object
#  2   Rating          9366 non-null   float64
#  3   Reviews         10840 non-null  object
#  4   Size            9145 non-null   float64
#  5   Installs        10840 non-null  int64
#  6   Type            10839 non-null  object
#  7   Price           10840 non-null  float64
#  8   Content Rating  10840 non-null  object
#  9   Genres          10840 non-null  object
#  10  Last Updated    10840 non-null  object
#  11  Current Ver     10832 non-null  object
#  12  Android Ver     10838 non-null  object
# dtypes: float64(3), int64(1), object(9)
# memory usage: 1.2+ MB

# %%
data_copy["Reviews"]=data_copy["Reviews"].astype("int")

# %%
data_copy['Last Updated']=pd.to_datetime(data_copy["Last Updated"])

# %%
data_copy["day"]=data_copy["Last Updated"].dt.day

# %%
data_copy["month"]=data_copy["Last Updated"].dt.month

# %%
data_copy["year"]=data_copy["Last Updated"].dt.year

# %%
data_copy.sample(2)
# Out:
#                   App  Category  Rating  Reviews    Size  Installs  Type  \
# 8166       TeeTime.cz    SPORTS     4.6     1641  6200.0     10000  Free
# 209   Plugin:AOT v5.0  BUSINESS     3.1     4034    23.0    100000  Free
#
#       Price Content Rating    Genres Last Updated           Current Ver  \
# 8166    0.0       Everyone    Sports   2018-08-02               1.18.34
# 209     0.0       Everyone  Business   2015-09-11  3.0.1.11 (Build 311)
#
#      Android Ver  day  month  year
# 8166  4.0 and up    2      8  2018
# 209   2.2 and up   11      9  2015

# %%
data_copy['Android Ver']=data_copy['Android Ver'].str.replace("and up","")

# %%
data_copy['Android Ver'].unique()
# Out:
# array(['4.0.3 ', '4.2 ', '4.4 ', '2.3 ', '3.0 ', '4.1 ', '4.0 ', '2.3.3 ',
#        'Varies with device', '2.2 ', '5.0 ', '6.0 ', '1.6 ', '1.5 ',
#        '2.1 ', '7.0 ', '5.1 ', '4.3 ', '4.0.3 - 7.1.1', '2.0 ', '3.2 ',
#        '4.4W ', '7.1 ', '7.0 - 7.1.1', '8.0 ', '5.0 - 8.0', '3.1 ',
#        '2.0.1 ', '4.1 - 7.1.1', nan, '5.0 - 6.0', '1.0 ', '2.2 - 7.1.1',
#        '5.0 - 7.1.1'], dtype=object)

# %%
data_copy['Android Ver']=data_copy['Android Ver'].str.replace( 'Varies with device',str(np.nan))

# %%
data_copy['Android Ver']=data_copy['Android Ver'].str.replace('W',"")

# %%
data_copy.to_csv("clean_playstore.csv",index='False')

# %%
df=pd.DataFrame({"col1":[1,2,3,4,4,5,5,56,6,6,],"col2":[2,3,5,34,45,454,56,46,56,43]})

# %%
import pandas as pd

# %%
df
# Out:
#    col1  col2
# 0     1     2
# 1     2     3
# 2     3     5
# 3     4    34
# 4     4    45
# 5     5   454
# 6     5    56
# 7    56    46
# 8     6    56
# 9     6    43

# %%
df.col1.duplicated()
# Out:
# 0    False
# 1    False
# 2    False
# 3    False
# 4     True
# 5    False
# 6     True
# 7    False
# 8    False
# 9     True
# Name: col1, dtype: bool

# %%
df.duplicated()
# Out:
# 0    False
# 1    False
# 2    False
# 3    False
# 4    False
# 5    False
# 6    False
# 7    False
# 8    False
# 9    False
# dtype: bool

# %%
data_copy
# Out:
#                                                      App             Category  \
# 0         Photo Editor & Candy Camera & Grid & ScrapBook       ART_AND_DESIGN
# 1                                    Coloring book moana       ART_AND_DESIGN
# 2      U Launcher Lite – FREE Live Cool Themes, Hide ...       ART_AND_DESIGN
# 3                                  Sketch - Draw & Paint       ART_AND_DESIGN
# 4                  Pixel Draw - Number Art Coloring Book       ART_AND_DESIGN
# ...                                                  ...                  ...
# 10836                                   Sya9a Maroc - FR               FAMILY
# 10837                   Fr. Mike Schmitz Audio Teachings               FAMILY
# 10838                             Parkinson Exercices FR              MEDICAL
# 10839                      The SCP Foundation DB fr nn5n  BOOKS_AND_REFERENCE
# 10840      iHoroscope - 2018 Daily Horoscope & Astrology            LIFESTYLE
#
# ...

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                        
warnings.filterwarnings("ignore")

# %matplotlib inline

# %%
data_copy.describe().T
# Out:
#             count          mean           std     min     25%       50%  \
# Rating     9366.0  4.191757e+00  5.152189e-01     1.0     4.0       4.3
# Reviews   10840.0  4.441529e+05  2.927761e+06     0.0    38.0    2094.0
# Size       9145.0  2.150653e+04  2.259602e+04    10.0  4900.0   13000.0
# Installs  10840.0  1.546434e+07  8.502936e+07     0.0  1000.0  100000.0
# Price     10840.0  1.027368e+00  1.594970e+01     0.0     0.0       0.0
# day       10840.0  1.560904e+01  9.561621e+00     1.0     6.0      16.0
# month     10840.0  6.422325e+00  2.578388e+00     1.0     5.0       7.0
# year      10840.0  2.017400e+03  1.100914e+00  2010.0  2017.0    2018.0
#
#                 75%           max
# Rating          4.5  5.000000e+00
# Reviews     54775.5  7.815831e+07
# Size        30000.0  1.000000e+05
# Installs  5000000.0  1.000000e+09
# Price           0.0  4.000000e+02
# day            24.0  3.100000e+01
# month           8.0  1.200000e+01
# year         2018.0  2.018000e+03

# %%
data_copy[data_copy.duplicated()]
# Out:
#                                                    App      Category  Rating  \
# 229                       Quick PDF Scanner + OCR FREE      BUSINESS     4.2
# 236                                                Box      BUSINESS     4.2
# 239                                 Google My Business      BUSINESS     4.4
# 256                                ZOOM Cloud Meetings      BUSINESS     4.4
# 261                          join.me - Simple Meetings      BUSINESS     4.0
# ...                                                ...           ...     ...
# 8643                    Wunderlist: To-Do List & Tasks  PRODUCTIVITY     4.6
# 8654   TickTick: To Do List with Reminder, Day Planner  PRODUCTIVITY     4.6
# 8658                           ColorNote Notepad Notes  PRODUCTIVITY     4.6
# 10049        Airway Ex - Intubate. Anesthetize. Train.       MEDICAL     4.3
# 10768                                             AAFP       MEDICAL     3.8
#
# ...

# %%
data_copy[data_copy.duplicated('Reviews')]
# Out:
#                                           App             Category  Rating  \
# 4       Pixel Draw - Number Art Coloring Book       ART_AND_DESIGN     4.3
# 57                 Extreme Rally Championship    AUTO_AND_VEHICLES     4.2
# 126              Skin Care and Natural Beauty               BEAUTY     NaN
# 134             Lady adviser (beauty, health)               BEAUTY     NaN
# 156    Offline: English to Tagalog Dictionary  BOOKS_AND_REFERENCE     4.7
# ...                                       ...                  ...     ...
# 10835                                FR Forms             BUSINESS     NaN
# 10836                        Sya9a Maroc - FR               FAMILY     4.5
# 10837        Fr. Mike Schmitz Audio Teachings               FAMILY     5.0
# 10838                  Parkinson Exercices FR              MEDICAL     NaN
# 10839           The SCP Foundation DB fr nn5n  BOOKS_AND_REFERENCE     4.5
#
#        Reviews     Size  Installs  Type  Price Content Rating  \
# ...

# %%
data_copy
# Out:
#                                                      App             Category  \
# 0         Photo Editor & Candy Camera & Grid & ScrapBook       ART_AND_DESIGN
# 1                                    Coloring book moana       ART_AND_DESIGN
# 2      U Launcher Lite – FREE Live Cool Themes, Hide ...       ART_AND_DESIGN
# 3                                  Sketch - Draw & Paint       ART_AND_DESIGN
# 4                  Pixel Draw - Number Art Coloring Book       ART_AND_DESIGN
# ...                                                  ...                  ...
# 10836                                   Sya9a Maroc - FR               FAMILY
# 10837                   Fr. Mike Schmitz Audio Teachings               FAMILY
# 10838                             Parkinson Exercices FR              MEDICAL
# 10839                      The SCP Foundation DB fr nn5n  BOOKS_AND_REFERENCE
# 10840      iHoroscope - 2018 Daily Horoscope & Astrology            LIFESTYLE
#
# ...

# %%
numarical_feature=[feature for feature in data_copy.columns if data_copy[feature].dtype!= 'O']

# %%
numarical_feature
# Out:
# ['Rating',
#  'Reviews',
#  'Size',
#  'Installs',
#  'Price',
#  'Last Updated',
#  'day',
#  'month',
#  'year']

# %%
data_copy.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 10840 entries, 0 to 10840
# Data columns (total 16 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   App             10840 non-null  object
#  1   Category        10840 non-null  object
#  2   Rating          9366 non-null   float64
#  3   Reviews         10840 non-null  int64
#  4   Size            9145 non-null   float64
#  5   Installs        10840 non-null  int64
#  6   Type            10839 non-null  object
#  7   Price           10840 non-null  float64
#  8   Content Rating  10840 non-null  object
#  9   Genres          10840 non-null  object
#  10  Last Updated    10840 non-null  datetime64[ns]
#  11  Current Ver     10832 non-null  object
#  12  Android Ver     10838 non-null  object
#  13  day             10840 non-null  int64
#  14  month           10840 non-null  int64
#  15  year            10840 non-null  int64
# ...

# %%
categorical_feature=[feature for feature in data_copy.columns if data_copy[feature].dtype=='O']

# %%
categorical_feature
# Out:
# ['App',
#  'Category',
#  'Type',
#  'Content Rating',
#  'Genres',
#  'Current Ver',
#  'Android Ver']

# %%
data_copy['Type'].value_counts()
# Out:
# Free    10039
# Paid      800
# Name: Type, dtype: int64

# %%
for col in categorical_feature:
  print(f"{col}:{data_copy[col].value_counts(normalize=True)*100}")
  print("=========================================")
# Out:
# App:ROBLOX                                                0.083026
# CBS Sports App - Scores, News, Stats & Watch Live     0.073801
# ESPN                                                  0.064576
# Duolingo: Learn Languages Free                        0.064576
# Candy Crush Saga                                      0.064576
#                                                         ...
# Meet U - Get Friends for Snapchat, Kik & Instagram    0.009225
# U-Report                                              0.009225
# U of I Community Credit Union                         0.009225
# Waiting For U Launcher Theme                          0.009225
# iHoroscope - 2018 Daily Horoscope & Astrology         0.009225
# Name: App, Length: 9659, dtype: float64
# ...
# Category:FAMILY                 18.191882
# GAME                   10.553506
# TOOLS                   7.776753
# MEDICAL                 4.271218
# BUSINESS                4.243542
# PRODUCTIVITY            3.911439
# ...

# %%
sns.countplot(x=data_copy["Type"])
# Out:
# <Axes: xlabel='Type', ylabel='count'>

# %%
plt.figure(figsize=(20, 15))
plt.suptitle('Univariate Analysis of Categorical Features', fontsize=20, fontweight='bold', alpha=0.8, y=1.)
category = [ 'Type', 'Content Rating']
for i in range(0, len(category)):
    plt.subplot(2, 2, i+1)
    sns.countplot(x=data_copy[category[i]],palette="Set2")
    plt.xlabel(category[i])
    plt.xticks(rotation=45)
    plt.tight_layout()

# %%
sns.kdeplot(data_copy["Price"])
# Out:
# <Axes: xlabel='Price', ylabel='Density'>

# %%
plt.hist(data_copy["Rating"])
plt.show()

# %%
plt.figure(figsize=(15, 15))
plt.suptitle('Univariate Analysis of Numarical Features', fontsize=20, fontweight='bold', alpha=0.8, y=1.)

for i in range(0, len(numarical_feature)):
    plt.subplot(5, 3, i+1)
    sns.kdeplot(x=data_copy[numarical_feature[i]],shade=True, color='r')
    plt.xlabel(numarical_feature[i])
    plt.tight_layout()

# %%
data_copy.head(2)
# Out:
#                                               App        Category  Rating  \
# 0  Photo Editor & Candy Camera & Grid & ScrapBook  ART_AND_DESIGN     4.1
# 1                             Coloring book moana  ART_AND_DESIGN     3.9
#
#    Reviews     Size  Installs  Type  Price Content Rating  \
# 0      159  19000.0     10000  Free    0.0       Everyone
# 1      967  14000.0    500000  Free    0.0       Everyone
#
#                       Genres Last Updated Current Ver Android Ver  day  month  \
# 0               Art & Design   2018-01-07       1.0.0      4.0.3     7      1
# 1  Art & Design;Pretend Play   2018-01-15       2.0.0      4.0.3    15      1
#
#    year
# 0  2018
# 1  2018

# %%
data_copy["Category"].value_counts().plot.pie(figsize=(15,15),autopct='%1.1f%%')
# Out:
# <Axes: ylabel='Category'>

# %%
df_cat=data_copy["Category"].value_counts()[:10]

# %%
category = pd.DataFrame(data_copy['Category'].value_counts())        #Dataframe of apps on the basis of category
category.rename(columns = {'Category':'Count'},inplace=True)

# %%
plt.figure(figsize=(15,6))
sns.barplot(x=df_cat, y ='Count',data= category[:10],palette='hls')
plt.title('Top 10 App categories')
plt.xticks(rotation=90)
plt.show()

# %%
type(data_copy.groupby(['Category'])['Installs'].sum().sort_values(ascending=False))
# Out:
# pandas.core.series.Series

# %%
df_cat_installs=data_copy.groupby(['Category'])['Installs'].sum().sort_values(ascending=False).reset_index()

# %%
df2=df_cat_installs.head(10)

# %%
sns.barplot(x="Installs",y="Category",data=df2)
# Out:
# <Axes: xlabel='Installs', ylabel='Category'>

# %%
#install_-app-category

# %%
dfa=data_copy.groupby(['App','Category'])['Installs'].sum().reset_index()

# %%
dfa
# Out:
#                                                    App       Category  \
# 0                 "i DT" Fútbol. Todos Somos Técnicos.         SPORTS
# 1                        +Download 4 Instagram Twitter         SOCIAL
# 2                           - Free Comics - Comic Apps         COMICS
# 3                                                   .R          TOOLS
# 4                                               /u/app  COMMUNICATION
# ...                                                ...            ...
# 9739                           뽕티비 - 개인방송, 인터넷방송, BJ방송  VIDEO_PLAYERS
# 9740                                        💎 I'm rich      LIFESTYLE
# 9741     💘 WhatsLov: Smileys of love, stickers and GIF         SOCIAL
# 9742  📏 Smart Ruler ↔️ cm/inch measuring for homework!          TOOLS
# 9743  🔥 Football Wallpapers 4K | Full HD Backgrounds 😍  ENTERTAINMENT
#
#       Installs
# 0          500
# 1      1000000
# 2        10000
# 3        10000
# 4        10000
# ...        ...
# ...

# %%
dfa=dfa.sort_values('Installs',ascending=False)

# %%
dfa
# Out:
#                              App            Category    Installs
# 8151              Subway Surfers                GAME  6000000000
# 5445                   Instagram              SOCIAL  4000000000
# 4976               Google Photos         PHOTOGRAPHY  4000000000
# 4972                 Google News  NEWS_AND_MAGAZINES  4000000000
# 4963                Google Drive        PRODUCTIVITY  4000000000
# ...                          ...                 ...         ...
# 8224           Sweden Newspapers  NEWS_AND_MAGAZINES           0
# 2663   Command & Conquer: Rivals              FAMILY           0
# 582   Ain Arabic Kids Alif Ba ta              FAMILY           0
# 8388      Test Application DT 02      ART_AND_DESIGN           0
# 4047                 Eu Sou Rico             FINANCE           0
#
# [9744 rows x 3 columns]

# %%
dfa[dfa.Category=='GAME'][:5]
# Out:
#                    App Category    Installs
# 8151    Subway Surfers     GAME  6000000000
# 2377  Candy Crush Saga     GAME  3000000000
# 8377      Temple Run 2     GAME  3000000000
# 7180               Pou     GAME  1500000000
# 6489    My Talking Tom     GAME  1000000000

# %%
plt.figure(figsize=(15,15))
sns.barplot(x="Category",y='Installs',data=dfa)
# Out:
# <Axes: xlabel='Category', ylabel='Installs'>

# %%
how many app in google play has 5 rating?

# %%
df1=data_copy.groupby(['App'])['Rating'].mean().sort_values(ascending=False).reset_index()

# %%
df1['Rating']
# Out:
# 0       5.0
# 1       5.0
# 2       5.0
# 3       5.0
# 4       5.0
#        ...
# 9654    NaN
# 9655    NaN
# 9656    NaN
# 9657    NaN
# 9658    NaN
# Name: Rating, Length: 9659, dtype: float64

# %%
data_copy['Rating']
# Out:
# 0        4.1
# 1        3.9
# 2        4.7
# 3        4.5
# 4        4.3
#         ...
# 10836    4.5
# 10837    5.0
# 10838    NaN
# 10839    4.5
# 10840    4.5
# Name: Rating, Length: 10840, dtype: float64

# %%
df1[df1.Rating==5.0]
# Out:
#                             App  Rating
# 0       AJ Rafael Music Lessons     5.0
# 1                    EC Calgary     5.0
# 2     Cloud DX Connected Health     5.0
# 3                    EB Scanner     5.0
# 4                CJ Gospel Hour     5.0
# ..                          ...     ...
# 266         Cr Aviation Academy     5.0
# 267  meStudying: AP English Lit     5.0
# 268                      211:CK     5.0
# 269                 DN Employee     5.0
# 270                   CZ Kompas     5.0
#
# [271 rows x 2 columns]

# %%
df2 = data_copy.groupby(['Category','Installs', 'App'])['Rating'].mean().sort_values(ascending = False).reset_index()

# %%
df2
# Out:
#                 Category  Installs                                        App  \
# 0         ART_AND_DESIGN       100    Spring flowers theme couleurs d t space
# 1        PERSONALIZATION        10                     AJ Gray Dark Icon Pack
# 2     NEWS_AND_MAGAZINES      1000                                    BI News
# 3     NEWS_AND_MAGAZINES       100              Startupticker.ch News, Events
# 4     NEWS_AND_MAGAZINES       100                      Noticias FC Barcelona
# ...                  ...       ...                                        ...
# 9747             WEATHER       500                           Ag Weather Tools
# 9748             WEATHER       500                            Weather Data CH
# 9749             WEATHER      1000                                Skywatch BL
# 9750             WEATHER      1000  WSVN • South Florida's Source for Weather
# 9751             WEATHER      1000                Wind & Weather Meter for Ag
#
#       Rating
# 0        5.0
# ...

# %%
data_copy.columns
# Out:
# Index(['App', 'Category', 'Rating', 'Reviews', 'Size', 'Installs', 'Type',
#        'Price', 'Content Rating', 'Genres', 'Last Updated', 'Current Ver',
#        'Android Ver', 'day', 'month', 'year'],
#       dtype='object')

# %%
plt.figure(figsize=(15,15))
sns.scatterplot(x='Price',y='Category',data=data_copy)
# Out:
# <Axes: xlabel='Price', ylabel='Category'>

# %%
data_copy.value_counts('Type').plot.pie(y='Type')
# Out:
# <Axes: >

# %%
plt.figure(figsize=(10,10))
sns.boxplot(x="Installs",y="Rating",data=data_copy)
plt.xticks(size=15,rotation=90)
plt.show()

# %% [markdown]
# Which Category are of largest size ??

# %%
plt.figure(figsize=(15,15))
plt.xticks(rotation = 90)
sns.barplot(x='Category',y='Size',data=data_copy)
plt.show()

# %%
p=pd.Series()

# %%
p=data_copy['year'].value_counts()

# %%
p
# Out:
# 2018    7349
# 2017    1867
# 2016     804
# 2015     459
# 2014     209
# 2013     110
# 2012      26
# 2011      15
# 2010       1
# Name: year, dtype: int64

# %%
p.plot()
# Out:
# <Axes: >
